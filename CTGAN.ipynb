# %%
# !pip install table_evaluator
# !pip install dython
# !pip install ctgan
# !pip install pandas

# %%
import pandas as pd
import dython
data = pd.read_csv('dataset/customer_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# categorical_features = ['Age','Gender','Purchase Amount (USD)','Frequency of Purchases']
categorical_features = ['customerID',	'gender',	'SeniorCitizen',	'Partner',	'Dependents',	'tenure',	'PhoneService',	'MultipleLines',	'InternetService',	'OnlineSecurity',	'OnlineBackup',	'DeviceProtection',	'TechSupport',	'StreamingTV',	'StreamingMovies',	'Contract',	'PaperlessBilling',	'PaymentMethod',	'MonthlyCharges',	'TotalCharges',	'Churn']

# %%
from ctgan import CTGAN

ctgan = CTGAN(verbose=True)
ctgan.fit(data, categorical_features, epochs = 200)
# Out:
# Gen. (0.70) | Discrim. (-0.11): 100%|██████████| 200/200 [44:30<00:00, 13.35s/it]

# %%
import pandas as pd

synthetic_data = ctgan.sample(1000)
df_synthetic = pd.DataFrame(synthetic_data)

df_synthetic.to_csv('synthetic_data.csv', index=False)

# %%
samples
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    5243-SAOTC  Female              1      No        Yes      27
# 1    7636-XUHWW  Female              0      No         No       5
# 2    0430-IHCDJ  Female              0     Yes         No      25
# 3    5982-PSMKW    Male              0      No         No      24
# 4    0013-SMEOE  Female              1     Yes         No      24
# ..          ...     ...            ...     ...        ...     ...
# 995  2108-GLPQB    Male              0     Yes         No      31
# 996  8232-UTFOZ    Male              0      No         No      10
# 997  4884-TVUQF  Female              1     Yes         No      69
# 998  6680-NENYN    Male              0     Yes         No      18
# 999  2176-OSJUV    Male              1     Yes         No      59
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0            Yes                No             DSL                   No  ...
# ...

# %%
from table_evaluator import TableEvaluator
print(data.shape, samples.shape)
# table_evaluator =  TableEvaluator(data, samples, cat_cols= categorical_features)
# print(table_evaluator)
# table_evaluator.visual_evaluation()
# Out:
# (7043, 21) (1000, 21)
